# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/HITESH/Downloads/Desktop/python 30 days/Downloads/employee_dataset_P4.csv")

# %%
df.head()
# Out:
#    EmployeeID        Name Department  Age  Salary
# 0           1  Employee_1         IT   53  107575
# 1           2  Employee_2    Finance   53   36655
# 2           3  Employee_3      Sales   25  100031
# 3           4  Employee_4         IT   51  106429
# 4           5  Employee_5         IT   58  117922

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  200 non-null    int64
#  1   Name        200 non-null    str
#  2   Department  200 non-null    str
#  3   Age         200 non-null    int64
#  4   Salary      200 non-null    int64
# dtypes: int64(3), str(2)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        EmployeeID         Age         Salary
# count  200.000000  200.000000     200.000000
# mean   100.500000   42.060000   77551.045000
# std     57.879185   11.456117   26464.369472
# min      1.000000   22.000000   30412.000000
# 25%     50.750000   32.000000   54171.750000
# 50%    100.500000   44.000000   80905.000000
# 75%    150.250000   53.000000   99732.500000
# max    200.000000   59.000000  119643.000000

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           0
# Salary        0
# dtype: int64

# %%
df.fillna(df.select_dtypes(include='number').mean(), inplace=True)
# Out:
#      EmployeeID          Name Department  Age  Salary
# 0             1    Employee_1         IT   53  107575
# 1             2    Employee_2    Finance   53   36655
# 2             3    Employee_3      Sales   25  100031
# 3             4    Employee_4         IT   51  106429
# 4             5    Employee_5         IT   58  117922
# ..          ...           ...        ...  ...     ...
# 195         196  Employee_196  Marketing   34  116900
# 196         197  Employee_197  Marketing   28  119112
# 197         198  Employee_198    Finance   57   41130
# 198         199  Employee_199      Sales   41  117508
# 199         200  Employee_200         IT   22   90566
#
# [200 rows x 5 columns]

# %%
numeric_df = df.select_dtypes(include='number')

# %%
sns.boxplot(x=df['Age'])
plt.show()
